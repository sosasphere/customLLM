# %%
from importlib.metadata import version

pkgs = ["matplotlib", 
        "numpy", 
        "tiktoken", 
        "torch",
       ]
for p in pkgs:
    print(f"{p} version: {version(p)}")

import torch
from supplementary import GPTModel


GPT_CONFIG_124M = {
    "vocab_size": 50257,   # Vocabulary size
    "context_length": 256, # Shortened context length (orig: 1024)
    "emb_dim": 768,        # Embedding dimension
    "n_heads": 12,         # Number of attention heads
    "n_layers": 12,        # Number of layers
    "drop_rate": 0.1,      # Dropout rate
    "qkv_bias": False      # Query-key-value bias
}

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.eval();  # Disable dropout during inference

import tiktoken
from supplementary import generate_text_simple


def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

start_context = "Every effort moves you"
tokenizer = tiktoken.get_encoding("gpt2")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)

with open("trainingDataSmall.txt", "r", encoding="utf-8") as file:
    text_data = file.read()

total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

from supplementary import create_dataloader_v1


# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

train_tokens = 0
for input_batch, target_batch in train_loader:
    train_tokens += input_batch.numel()

val_tokens = 0
for input_batch, target_batch in val_loader:
    val_tokens += input_batch.numel()

from supplementary import calc_loss_loader


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print(device)
print("Training loss:", train_loss)
print("Validation loss:", val_loss)

from supplementary import (
    calc_loss_batch,
    evaluate_model,
    generate_and_print_sample
)


def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

num_epochs = 10
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="A chargeback fee is a", tokenizer=tokenizer
)

torch.save(model, "model.pth")

start_context = "What is Account Updater?"
tokenizer = tiktoken.get_encoding("gpt2")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=40,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# matplotlib version: 3.9.2
# numpy version: 1.26.3
# tiktoken version: 0.8.0
# torch version: 2.5.1+cu118
# cuda
# Training loss: 10.986106736319405
# Validation loss: 11.015321254730225
# Ep 1 (Step 000000): Train loss 9.693, Val loss 9.645
# Ep 1 (Step 000005): Train loss 8.018, Val loss 8.207
# Ep 1 (Step 000010): Train loss 6.712, Val loss 7.099
# A chargeback fee is a.
# Ep 2 (Step 000015): Train loss 5.750, Val loss 6.788
# Ep 2 (Step 000020): Train loss 5.640, Val loss 6.602
# Ep 2 (Step 000025): Train loss 5.335, Val loss 6.638
# A chargeback fee is a and the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# Ep 3 (Step 000030): Train loss 5.064, Val loss 6.450
# Ep 3 (Step 000035): Train loss 4.619, Val loss 6.421
# Ep 3 (Step 000040): Train loss 4.319, Val loss 6.347
# A chargeback fee is a customer is a customer is, and the card information, and businesses, and businesses to to ensure that the merchant, and the merchant, and businesses, the transaction.
# Ep 4 (Step 000045): Train loss 4.037, Val loss 6.468
# Ep 4 (Step 000050): Train loss 3.200, Val loss 6.463
# Ep 4 (Step 000055): Train loss 3.081, Val loss 6.347
# A chargeback fee is a tokenization:
# Ep 5 (Step 000060): Train loss 2.830, Val loss 6.359
# Ep 5 (Step 000065): Train loss 2.722, Val loss 6.373
# A chargeback fee is a significant a significant momentum in the 1990s and early 2000s as e-commerce, and payment processing payments and the transaction details, and the payment processing, and other digital wallets, and its to the merchant, and has become.
# Ep 6 (Step 000070): Train loss 2.160, Val loss 6.365
# Ep 6 (Step 000075): Train loss 1.928, Val loss 6.365
# Ep 6 (Step 000080): Train loss 1.630, Val loss 6.430
# A chargeback fee is a significant.     As businesses, payment processors, as a token, Account Updater services will become a global payment processing, the payment systems.  Account Updater services to businesses, the payment processing.
# Ep 7 (Step 000085): Train loss 1.350, Val loss 6.432
# Ep 7 (Step 000090): Train loss 1.138, Val loss 6.502
# Ep 7 (Step 000095): Train loss 0.882, Val loss 6.450
# A chargeback fee is a significant role of the largest payment processors like Netflix and even regional preferences, and businesses to tailor their offerings and with it, the demand for secure and reliable payment systems.  In 2019, Worldpay’s as a significant of payment processing remains
# Ep 8 (Step 000100): Train loss 0.784, Val loss 6.505
# Ep 8 (Step 000105): Train loss 0.664, Val loss 6.637
# Ep 8 (Step 000110): Train loss 0.497, Val loss 6.669
# A chargeback fee is a significant role of data updates, Worldpay’s established infrastructure. These wallets store card information digitally and with it, Worldpay’s technology thus goes beyond simply processing payments have transformed commerce. Through these services, Worldpay not only facilitates
# Ep 9 (Step 000115): Train loss 0.429, Val loss 6.665
# Ep 9 (Step 000120): Train loss 0.393, Val loss 6.711
# Ep 9 (Step 000125): Train loss 0.265, Val loss 6.735
# A chargeback fee is a significant role. The company gained, Worldpay is poised to continue as a leader in the payment processing industry. As it navigates the challenges and reliable payment systems.  In 2019, Worldpay underwent a transformative change when it merged with FIS
# Ep 10 (Step 000130): Train loss 0.253, Val loss 6.876
# Ep 10 (Step 000135): Train loss 0.234, Val loss 6.779
# A chargeback fee is a significant momentum. Merchants generally access these services through their payment systems have evolved tremendously. Today, payments encompass a wide range of methods, including cash, checks, and other digital world, and are often used for payroll, creating a smoother and more reliable payment
# Output text:
#  What is Account Updater? card types of payment methods, the payment is ‘cleared, retain customers, and optimize revenue collection.
# How Account Updater Services Work
#
# Account Updater Providers and Services

# %%
start_context = "Account Updater?"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=55,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Account Updater?. By using Account Updater services, businesses can minimize disruptions in service, retain customers, and optimize revenue collection.
# As digital payments grow globally, linking payment methods (such as cards or digital wallets) with the merchant's account.
# Account Updater services have

# %%
start_context = "What is a cleared transaction?"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=50,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  What is a cleared transaction?, and contactless payments presents a growing demand for reliable payment processing services. This also minimizes the need for outreach to customers to request updated payment information.
#
# Account Updater Providers and Services
#
# Account Updater services are typically

# %%
start_context = "What is a POS transaction?"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=50,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  What is a POS transaction? of networks, and tap into FIS’s established infrastructure. These wallets store card information digitally and provide a fast, secure payment option.
# The them a powerful combination capable of handling massive volumes of transactions across various payment channels.
# 2.

# %%
start_context = "How is the weather"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=50,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  How is the weatherSince you only pay for matches, and Samsung Pay, is on the rise. These wallets store card information digitally and provide a fast, secure payment option.
# Account Updater services address this need by automatically updating stored cardholder information, reducing failed

# %%
from importlib.metadata import version

pkgs = ["matplotlib", 
        "numpy", 
        "tiktoken", 
        "torch",
       ]
for p in pkgs:
    print(f"{p} version: {version(p)}")

import torch
from supplementary import GPTModel


GPT_CONFIG_124M = {
    "vocab_size": 50257,   # Vocabulary size
    "context_length": 256, # Shortened context length (orig: 1024)
    "emb_dim": 768,        # Embedding dimension
    "n_heads": 12,         # Number of attention heads
    "n_layers": 12,        # Number of layers
    "drop_rate": 0.1,      # Dropout rate
    "qkv_bias": False      # Query-key-value bias
}

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.eval();  # Disable dropout during inference

import tiktoken
from supplementary import generate_text_simple


def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

start_context = "A chargeback "
tokenizer = tiktoken.get_encoding("gpt2")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)

with open("mediumTraining.txt", "r", encoding="utf-8") as file:
    text_data = file.read()

total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

from supplementary import create_dataloader_v1


# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

train_tokens = 0
for input_batch, target_batch in train_loader:
    train_tokens += input_batch.numel()

val_tokens = 0
for input_batch, target_batch in val_loader:
    val_tokens += input_batch.numel()

from supplementary import calc_loss_loader


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print(device)
print("Training loss:", train_loss)
print("Validation loss:", val_loss)

from supplementary import (
    calc_loss_batch,
    evaluate_model,
    generate_and_print_sample
)


def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")   

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

num_epochs = 10
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="A chargeback fee is a", tokenizer=tokenizer
)

torch.save(model, "model.pth")

start_context = "What is Account Updater?"
tokenizer = tiktoken.get_encoding("gpt2")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=40,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))

# %%
start_context = " What is Account Updater?"
tokenizer = tiktoken.get_encoding("gpt2")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=50,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#   What is Account Updater?
#
# PERICLES.
# He thinks not a man.
#
# THIRD FISHERMAN.
# ’Tis a goodly.
#
# THIRD FISHERMAN.
# He is a goodly raim.

# %%
start_context = "Tell me more about POS transactions"
tokenizer = tiktoken.get_encoding("gpt2")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=50,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Tell me more about POS transactions.
#
# [_Exit._]
#
# SCENE V. The same. The same. A room in the castle
#
# Enter Timon and Lance.
#
# FIRST FRIEND.
# I have told you, sir, I have been

# %%
start_context = "Tell me more about POS transactions"
tokenizer = tiktoken.get_encoding("gpt2")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer).to(device),
    max_new_tokens=50,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Tell me more about POS transactions.
#
# [_Exit._]
#
# SCENE V. The same. The same. A room in the Garter Inn
#
# Enter Host and Simple.
#
# HOST.
# I pray you, sir, I pray you, sir
